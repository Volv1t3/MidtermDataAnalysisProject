# %% [markdown]
# # <b>ADM 3083 — Herramientas y Visualización — Universidad San Francisco de Quito</b>
# <h2><b>Proyecto de Fin de Semestre</b></h2>
# <i>Lúnes, 20 de abril de 2026</i>
# <hr>
# <ul>
#     <li><b>Integrantes del Grupo</b>: Santiago Arellano [00328370]</li>
#     <li><b>NRC del Curso</b>: 2046</li>
#     <li><b>Profesor</b>: Juan Felipe Nájera Puente</li>
# </ul>

# %% [markdown]
# ## Sección I: Introducción al Proyecto
#
# El presente archivo define la parte analítica y de transformación de datos requerida para implementar la pipeline de procesamiento de datos para el dashboard final en Streamlit. El proyecto se basa en el análisis de datos del dataset **Super Store** un registro de ventas del minorista Superstore Giant, que registra los datos de ventas por regiónes de operación, categorías de productos, segmentos de productos, etc.
#
# El objetivo del proyecto es desarrollar una plataforma completa mantenida en GitHub que contenga el paso de preprocesamiento de datos como un paso adicional que puede ser ejecutado en local para la validación de los datos, mientras que una versión de los datos procesados se registran en el mismo repositorio, usando una referencia al archivo desde GitHub Raw para evitar problemas de rutas no reconocidas, o problemas de archivos incompletos a la hora de cargar el dataset completo. En base de los datos definidos en el repositorio, se implementará una visualización en Streamlit que implemente una dashboard interactiva que recopile y muestre la información más importante para la gerencia .

# %% [markdown]
# ### Información del dataset
#
# El dataset base contiene las siguientes columnas, estas se registran con el tipo de dato esperado y una definición de cada una de las columnas para facilitar la comprensión de los datos y su posterior análisis:
#
# <div style="display: flex; align-items:center; align-self:center; justify-content:center">
# <table style="margin: auto; border-collapse: collapse; width: 80%; text-align: center; border: 1px solid black;">
#     <thead>
#         <tr style="background-color: #f2f2f2;">
#             <th style="border: 1px solid black; padding: 8px;">Campo</th>
#             <th style="border: 1px solid black; padding: 8px;">Tipo de Dato Esperado</th>
#             <th style="border: 1px solid black; padding: 8px;">Descripción</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Row ID</td>
#             <td style="border: 1px solid black; padding: 8px;">Entero</td>
#             <td style="border: 1px solid black; padding: 8px;">Identificador único de fila</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Order ID</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Identificador único del pedido</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Order Date</td>
#             <td style="border: 1px solid black; padding: 8px;">Fecha</td>
#             <td style="border: 1px solid black; padding: 8px;">Fecha en que se realizó el pedido</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Ship Date</td>
#             <td style="border: 1px solid black; padding: 8px;">Fecha</td>
#             <td style="border: 1px solid black; padding: 8px;">Fecha de envío del pedido</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Ship Mode</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Modo de envío (Standard Class, Second Class, First Class, Same Day)</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Customer ID</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Identificador único del cliente</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Customer Name</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Nombre completo del cliente</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Segment</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Segmento de cliente (Consumer, Corporate, Home Office)</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Country</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">País del cliente</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">City</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Ciudad del cliente</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">State</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Estado o provincia del cliente</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Postal Code</td>
#             <td style="border: 1px solid black; padding: 8px;">Entero</td>
#             <td style="border: 1px solid black; padding: 8px;">Código postal del cliente</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Region</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Región geográfica (East, West, Central, South)</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Product ID</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Identificador único del producto</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Category</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Categoría principal del producto (Furniture, Office Supplies, Technology)</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Sub-Category</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Subcategoría específica del producto</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Product Name</td>
#             <td style="border: 1px solid black; padding: 8px;">Texto</td>
#             <td style="border: 1px solid black; padding: 8px;">Nombre completo del producto</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Sales</td>
#             <td style="border: 1px solid black; padding: 8px;">Flotante</td>
#             <td style="border: 1px solid black; padding: 8px;">Valor total de ventas en USD</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Quantity</td>
#             <td style="border: 1px solid black; padding: 8px;">Entero</td>
#             <td style="border: 1px solid black; padding: 8px;">Cantidad de productos vendidos</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Discount</td>
#             <td style="border: 1px solid black; padding: 8px;">Flotante</td>
#             <td style="border: 1px solid black; padding: 8px;">Descuento aplicado (como decimal de 0 a 1)</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid black; padding: 8px;">Profit</td>
#             <td style="border: 1px solid black; padding: 8px;">Flotante</td>
#             <td style="border: 1px solid black; padding: 8px;">Ganancia obtenida de la venta en USD</td>
#         </tr>
#     </tbody>
# </table>
# </div>

# %% [markdown]
# ## Sección II: Análisis base de las columnas de datos Para la Conversión y Transformación de Datos

# %%
#? 1. Importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as plty

# %%
#? 1. Escaneo de datos base, teniendo en cuenta tipos de datos anteriores.

data_url = "https://raw.githubusercontent.com/Volv1t3/MidtermDataAnalysisProject/Proyecto-Fin-Semestre/src/res/data/ProyectoFinSemestreADM3083_SuperstoreRaw.csv"

data_to_explore = pd.read_csv(data_url,sep=',', encoding=)

data_to_explore
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 5
#       1 #? 1. Escaneo de datos base, teniendo en cuenta tipos de datos anteriores.
#       3 data_url = "https://raw.githubusercontent.com/Volv1t3/MidtermDataAnalysisProject/Proyecto-Fin-Semestre/src/res/data/ProyectoFinSemestreADM3083_SuperstoreRaw.csv"
# ----> 5 data_to_explore = pd.read_csv(data_url,sep=',')
#       7 data_to_explore
#
# ...
